# %% [markdown]
# # Insert punny title here

# %% [markdown]
# ## Overview and Motivation

# %% [markdown]
# *Insert description here*
# This [title of report or article or dataset] contains information from the Harvard Library Bibliographic Dataset, which is provided by the Harvard Library under its Bibliographic Dataset Use Terms and includes data made available by, among others, OCLC Online Computer Library Center, Inc. and the Library of Congress.

# %% [markdown]
# ## Related Work

# %% [markdown]
# *More description*

# %% [markdown]
# ## Initial Questions

# %% [markdown]
# Our initial question with this dataset is whether we can predict the number of checkouts for a library item based on its attributes (e.g. year of publication, subject matter, holding library, etc.)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data Scraping

# %%
# Import all necessary modules
import sys
import pandas as pd
import json
import requests
from urllib2 import Request, urlopen
from pandas.io.json import json_normalize
import time
import numpy as np

# %% [markdown]
# Our data comes from the Harvard Library Open Metadata. A description of this data can be found at http://openmetadata.lib.harvard.edu. Briefly, this dataset contains over 12 million records of the items in Harvard's libraries. Since our question had to do with the number of checkouts for each item, we only took the subset of items which had at least one checkout by an undergraduate student.
#
# For the purpose of data scraping, we are using the Harvard LibraryCloud Item API (http://librarycloud.harvard.edu/v1/docs/item/). Since the number of items returned is capped at 250 per request, we wrote a few functions to help us grab all the data of interest.

# %%
# Create a list of valid search fields
valid_fields = []

# %%
def num_records(field, query):
    """
    Returns the number of records contained in 
    Harvard Library Metdata matching the given
    field and query
    """
    url = 'http://librarycloud.harvard.edu/v1/api/item/?filter='+str(field)+':'+str(query)
    r = requests.get(url)
    info = r.json()
    # num_records is the total number of records returns for the given field and query
    records = info['num_found']
    return records

# %%
def create_urls(field, query):
    """
    Returns a list of URLs which contain all 
    records of the given field and query
    """
    records = num_records(field, query)
    if records == 0:
        return
    # Create the base string for url that is to be modified and added to list
    base_url = 'http://librarycloud.harvard.edu/v1/api/item/?filter='+str(field)+':'+str(query)+'&limit=250'
    num_loops = records/250 + 1
    urls_list = []
    for i in xrange(num_loops):
        loop_url = base_url + '&start=' + str(i*250)
        urls_list.append(loop_url)
    return urls_list

# %%
def scrape_records(url):
    """
    Reads the JSON object at the given url and 
    returns the data as a Pandas dataframe
    """
    request = Request(url)
    cols = list()
    response = urlopen(request)
    books = response.read()
    data = json.loads(books)
    df = json_normalize(data['docs'])
    return df

# %% [markdown]
# ##### Find the maximum number of checkouts to use for scraping

# %%
# Check for a maximum of undergraduate checkouts to set parameter for scraping
checkout_min = 3800
checkout_max = 7000
# Preallocate memory for each entry in the list
checkout_list = [None]*(checkout_max-checkout_min)
for k in xrange(checkout_min, checkout_max):
    num_checkout = num_records('score_checkouts_undergrad', k)
    checkout_list[k-checkout_min] = k, num_checkout
df = pd.DataFrame(checkout_list)
# Print the maximum checkout number with at least 1 item returned by num_records
max(df.ix[df[1]>0][0])
# Out:
# 3868

# %% [markdown]
# One record has 3868 checkouts by undergraduates. Let's see what it is!

# %%
a = create_urls('score_checkouts_undergrad', 3868)
b = [scrape_records(a[j])for j in xrange(len(a)) ]
b[0].ix[0].title
# Out:
# u'Physics for scientists & engineers with modern physics'

# %% [markdown]
# Turns out it's *Physics for scientists and engineers with modern physics*.

# %% [markdown]
# ##### Get a master list of URLs to scrape using the API

# %% [markdown]
# Now we can make our master list of URLs from which we'll use the API to get the information into a pandas dataframe.

# %%
# Create master list of URLs - ONLY RUN ONCE! Next time can load from the file below
master_urls = [create_urls('score_checkouts_undergrad', i) for i in xrange(1, 3870)]

# %%
# Save the master url list
f = open('url_list', 'w')
json.dump(master_urls, f)
f.close()

# %%
# Load the master url list
f2 = open('url_list', 'r')
test = json.load(f2)

# %%
# Get rid of None values in master_urls
master_urls_filtered = filter(None, master_urls)
# Flatten the list of lists
flat_master_urls = [url for url_list in master_urls_filtered for url in url_list]
# Save the flattened, filtered list
f3 = open('filtered_url_list', 'w')
json.dump(flat_master_urls, f3)
f3.close()

# %% [markdown]
# ##### Get all the data into a Pandas Data Frame

# %% [markdown]
# ### START HERE for scraping data

# %%
# Load the master list of urls
f4 = open('filtered_url_list', 'r')
flat_master_urls = json.load(f4)
f4.close()

# %%
# Use a subset of the URLs to get a sense of how long scraping will take
test_urls = flat_master_urls[20:30]
# Use timeit in python to time the speed of the process
start = time.time()
test_df_list = [scrape_records(url) for url in test_urls]
end = time.time()
print 'It took %f seconds to scrape 10 urls' %(end-start)
# Out:
# It took 9.128630 seconds to scrape 10 urls

# %%
# Vectorize scrape_records
scrape_records_vec = np.vectorize(scrape_records)
start = time.time()
dtl = scrape_records_vec(flat_master_urls)
end = time.time()
print 'It took %f seconds to scrape all urls' %(end-start)
# Out:
# It took 3083.059208 seconds to scrape all urls

# %%
type(dtl)
# Out:
# numpy.ndarray

# %%
# Save the master scraped data
outfile = "scrapedData"
np.save(outfile, dtl)

# %%
# read the saved file back in 
np.load("scrapedData.npy")
# Out:
# array([                                               call_num  \
# 0                                     [E840 .K36 2005]
# 1                                  [DS371.4 .C43 2006]
# 2                                 [HC110.W4 C654 2006]
# 3                                   [KZ6311 .R43 2009]
# 4            [HV4140.B6 B66 2012, HV4140.M86 B66 2012]
# 5                                   [NK2715 .D33 2006]
# 6                                   [DK127 .I475 1998]
# 7                                 [KF228.G53 L49 1989]
# 8                                 [E175.5.F73 A3 2005]
# 9                                [LD3071.L33 R66 2009]
# 10                                [HQ1064.I4 L36 2000]
# 11               [QA3 .N49, QA3 .V594, QA3 .V594 1961]
# 12           [QC20.7.N6 E57 2001, QC20.7.N6 .E57 2001]
# 13                [PL2357 .M32 1990, PN2871 .M22 1990]
# 14                                  [K190 .R6813 1994]
# 15                                  [BL1571 .C46 2002]
# 16                                [KF5074.2 .P67 2001]
# 17                                  [NA6600 .E34 2000]
# 18        [NA6234.M42 K837 2001, NA6234.M42 K854 2001]
# 19         [HV6626.52 .C45 2005, HV6626.52 .C565 2005]
# 20                                [BS2595.3 .B58 1994]
# 21                                   [QA377 .Z38 1989]
# 22        [QC173.4 .C65 M6 . 30, QC176.8.M46 M47 1991]
# 23                                 [HV6431 .T557 2006]
# 24                                  [NA4605 .P45 1982]
# 25                                    [DE86 .C58 2007]
# 26                              [NA1123.P47 G566 1997]
# 27                                    [D883 .S36 1999]
# 28                                        [TR365 .R83]
# 29                                   [BL51 .C325 2001]
# ..                                                 ...
# 220                                 [LB1028 .F64 2004]
# 221                              [LB2806.22 .S36 2002]
# 222                                         [JC50 .K8]
# 223  [NA2500 .C75 1996, NA2500 .S6 1996, NA2560 .C8...
# 224                               [DS889.15 .F54 1991]
# 225  [N620.S63 A84 2009, N620.S63 G84 2009, NA6700....
# 226                                 [HB3731 .F69 2009]
# 227                                  [K4725 .H37 2005]
# 228                                  [BS575 .W39 1988]
# 229                                 [ML410.R2 C5 1993]
# 230                    [B128.C37 G7, B128.C37 G7 1958]
# 231                    [BQ1887 .P72, BQ1887 .P73 1977]
# 232  [BR60.F3 A85 1963, BR61.F38 P38 .45, BT110 .A813]
# 233                                 [F1230 .C833 1993]
# 234                                 [HM131 .B726 2000]
# 235                               [BQ4570.W6 I55 2000]
# 236                               [BQ4165 .P4794 1989]
# 237                                [DG70.T67 G89 2000]
# 238                         [BP55, BP191 .S51613 1984]
# 239  [LB2331.72 .N48 .117, LB2375 .I54 2002, LB2376...
# 240                                   [BM70 .O95 2002]
# 241                              [BQ7699.K34 W44 2005]
# 242  [PJ7541 .G5 1971, PJ 7541 .G5 1971, PJ7541 .G5...
# 243  [QB36.G2 G356 2001, QB36.G2 .G45 2001, QB36.G2...
# 244                              [DK508.772 .I45 2007]
# 245               [TT502 .M58 2001, TT502 .M5897 2001]
# 246   [R141 V57 2006, R141 .V57 2006, R141 .V57 2006X]
# 247                                 [NA2800 .M45 1999]
# 248                                  [JC585 .H29 1972]
# 249               [NA7451 .I92 2005, NA7451 .I93 2005]
#
#                                                creator  data_source  \
# 0                              [Katzenstein, Peter J.]  harvard_edu
# 1                               [Chayes, Sarah, 1962-]  harvard_edu
# 2           [Lui, Meizhu., United for a Fair Economy.]  harvard_edu
# 3    [Yates, Pamela., Kinoy, Peter., Onís, Paco de....  harvard_edu
# 4                                    [Boo, Katherine.]  harvard_edu
# 5                            [Dampierre, Florence de.]  harvard_edu
# 6                   [Burbank, Jane., Ransel, David L.]  harvard_edu
# 7                         [Lewis, Anthony, 1927-2013.]  harvard_edu
# 8                    [Franklin, John Hope, 1915-2009.]  harvard_edu
# 9                                      [Roose, Kevin.]  harvard_edu
# 10                                [Lamb, Sarah, 1960-]  harvard_edu
# 11                     [Von Neumann, John, 1903-1957.]  harvard_edu
# 12          [Enns, Richard H., McGuire, George, 1940-]  harvard_edu
# 13                                 [Mackerras, Colin.]  harvard_edu
# 14                                 [Rouland, Norbert.]  harvard_edu
# 15   [Choksy, Jamsheed K. (Jamsheed Kairshasp), 1962-]  harvard_edu
# 16                                [Posner, Richard A.]  harvard_edu
# 17                             [Edwards, Brian, 1944-]  harvard_edu
# 18                [Pelli, Cesar., Crosbie, Michael J.]  harvard_edu
# 19   [Giacomoni, Sarah M., ed., Kendall-Tackett, Ka...  harvard_edu
# 20                                  [Bock, Darrell L.]  harvard_edu
# 21                                  [Zauderer, Erich.]  harvard_edu
# 22   [Alʹtshuler, B. L., Lee, P. A. (Patrick A.), 1...  harvard_edu
# 23   [Jones, Alex, 1974-, Infowars.com., Jones Prod...  harvard_edu
# 24                                   [Pennick, Nigel.]  harvard_edu
# 25           [Alcock, Susan E., Osborne, Robin, 1957-]  harvard_edu
# 26   [Piano, Renzo., Kunst- und Ausstellungshalle d...  harvard_edu
# 27                               [Scott, David, 1958-]  harvard_edu
# 28                                [Rudisill, Richard.]  harvard_edu
# 29                                   [Caputo, John D.]  harvard_edu
# ..                                                 ...          ...
# 220  [DeMarrais, Kathleen Bennett., Lapan, Stephen D.]  harvard_edu
# 221  [Evers, Williamson M., 1948-, Walberg, Herbert...  harvard_edu
# 222  [Shang, Yang, -338 B.C., Duyvendak, J. J. L. (...  harvard_edu
# 223  [Speaks, Michael., Haan, Jasper de., Stylos Cr...  harvard_edu
# 224                              [Field, Norma, 1947-]  harvard_edu
# 225                                                NaN  harvard_edu
# 226                               [Fox, Justin, 1964-]  harvard_edu
# 227                                [Happold, Matthew.]  harvard_edu
# 228                          [Weems, Renita J., 1954-]  harvard_edu
# 229                      [Christensen, Thomas Street.]  harvard_edu
# 230                   [Graham, A. C. (Angus Charles).]  harvard_edu
# 231  [Conze, Edward, 1904-1979., Lancaster, Lewis R...  harvard_edu
# 232  [Augustine, Saint, Bishop of Hippo., McKenna, ...  harvard_edu
# 233  [Cortés, Hernán, 1485-1547., Delgado Gómez, An...  harvard_edu
# 234                             [Brown, Rupert, 1950-]  harvard_edu
# 235              [Karma Lekshe Tsomo, Bhikṣuṇī, 1944-]  harvard_edu
# 236  [Phra Thēpwisutthimēthī (Ngư̄am), 1906-1993., ...  harvard_edu
# 237  [Guzzo, Pier Giovanni., Fergola, Lorenzo., Mot...  harvard_edu
# 238  [Shahrastānī, Muḥammad ibn ʻAbd al-Karīm, 1086...  harvard_edu
# 239               [Speck, Bruce W., Carmical, Beth H.]  harvard_edu
# 240  [Goodman, Martin, 1953-, Cohen, Jeremy, 1953-,...  harvard_edu
# 241  [Herzog, Werner, 1942-, Stupetíc, Lucki., Wern...  harvard_edu
# 242  [Giorgio Levi Della Vida Conference 1971 : Uni...  harvard_edu
# 243                              [Renn, Jürgen, 1956-]  harvard_edu
# 244                                [Yekelchyk, Serhy.]  harvard_edu
# 245  [Miyake, Issei, 1938-, Fujiwara, Dai, 1967-, K...  harvard_edu
# 246  [Givens, Jean A. (Jean Ann), 1947-, Reeds, Kar...  harvard_edu
# 247  [Mehta, Madan., Johnson, James (James Allison)...  harvard_edu
# 248  [Hayek, Friedrich A. von (Friedrich August), 1...  harvard_edu
# 249                [Iwatate, Marcia., Mehta, Geeta K.]  harvard_edu
#
#                              dataset_tag      format      height  \
# 0    harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 1    harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 2    harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 3    harvard_edu_catalog_bibs_1385882476  Video/Film    4 3/4 in
# 4    harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 5    harvard_edu_catalog_bibs_1385882476        Book       28 cm
# 6    harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 7    harvard_edu_catalog_bibs_1385882476        Book       21 cm
# 8    harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 9    harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 10   harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 11   harvard_edu_catalog_bibs_1385882476        Book       26 cm
# 12   harvard_edu_catalog_bibs_1385882476        Book    26 cm. +
# 13   harvard_edu_catalog_bibs_1385882476        Book       21 cm
# 14   harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 15   harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 16   harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 17   harvard_edu_catalog_bibs_1385882476        Book       28 cm
# 18   harvard_edu_catalog_bibs_1385882476        Book       29 cm
# 19   harvard_edu_catalog_bibs_1385882476        Book       26 cm
# 20   harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 21   harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 22   harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 23   harvard_edu_catalog_bibs_1385882476  Video/Film    4 3/4 in
# 24   harvard_edu_catalog_bibs_1385882476        Book       21 cm
# 25   harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 26   harvard_edu_catalog_bibs_1385882476        Book  23 x 23 cm
# 27   harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 28   harvard_edu_catalog_bibs_1385882476        Book       29 cm
# 29   harvard_edu_catalog_bibs_1385882476        Book       21 cm
# ..                                   ...         ...         ...
# 220  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 221  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 222  harvard_edu_catalog_bibs_1385882476        Book       20 cm
# 223  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 224  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 225  harvard_edu_catalog_bibs_1385882476        Book       31 cm
# 226  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 227  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 228  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 229  harvard_edu_catalog_bibs_1385882476        Book       26 cm
# 230  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 231  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 232  harvard_edu_catalog_bibs_1385882476        Book       22 cm
# 233  harvard_edu_catalog_bibs_1385882476        Book       19 cm
# 234  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 235  harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 236  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 237  harvard_edu_catalog_bibs_1385882476        Book       29 cm
# 238  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 239  harvard_edu_catalog_bibs_1385882476        Book       23 cm
# 240  harvard_edu_catalog_bibs_1385882476        Book       26 cm
# 241  harvard_edu_catalog_bibs_1385882476  Video/Film    4 3/4 in
# 242  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 243  harvard_edu_catalog_bibs_1385882476        Book       25 cm
# 244  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 245  harvard_edu_catalog_bibs_1385882476        Book  30 x 25 cm
# 246  harvard_edu_catalog_bibs_1385882476        Book       24 cm
# 247  harvard_edu_catalog_bibs_1385882476        Book       29 cm
# 248  harvard_edu_catalog_bibs_1385882476        Book       21 cm
# 249  harvard_edu_catalog_bibs_1385882476        Book       32 cm
#
#      height_numeric                              holding_libs  \
# 0                25                                     [WID]
# 1                25                           [KSG, LAM, WID]
# 2                24                           [BAK, DIV, WID]
# 3               NaN                                     [LAW]
# 4                25                           [LAM, WID, DES]
# 5                28                                [DES, WID]
# 6                25                                [WID, FUN]
# 7                21                                     [LAW]
# 8                24                      [LAM, WID, GUT, LAW]
# 9                24                           [DIV, GUT, WID]
# 10               24                                [TOZ, WID]
# 11               26                      [WID, PHY, WOL, BIR]
# 12               26                           [WOL, CAB, PHY]
# 13               21                           [WID, HYL, FUN]
# 14               23                                [WID, LAW]
# 15               23                                     [DIV]
# 16               24                           [LAM, LAW, WID]
# 17               28                                     [DES]
# 18               29                                     [DES]
# 19               26                                     [GUT]
# 20               24                                     [DIV]
# 21               25                                [CAB, MCK]
# 22               25                                     [MCK]
# 23              NaN                                     [KSG]
# 24               21                                     [DES]
# 25               25  [NET, SMY, DIV, TOZ, FAL, WID, HEL, LAM]
# 26               23                                     [DES]
# 27               24                                [TOZ, WID]
# 28               29                                     [FAL]
# 29               21                           [DIV, WID, LAM]
# ..              ...                                       ...
# 220              23                                     [GUT]
# 221              24                                     [GUT]
# 222              20                      [WID, LAW, RUB, HYL]
# 223              23                                [DDO, DES]
# 224              23                      [LAM, HYL, WID, FUN]
# 225              31                                [WID, DES]
# 226              24                                [WID, NET]
# 227              24                                     [LAW]
# 228              23                                [SCH, DIV]
# 229              26                                     [MUS]
# 230              23                           [WID, HYL, DIV]
# 231              23                                [WID, DIV]
# 232              22            [NET, DIV, PHI, BER, WID, DDO]
# 233              19                                [WID, LAM]
# 234              24                                     [WID]
# 235              25                                     [DIV]
# 236              24                                [WID, DIV]
# 237              29                                     [FAL]
# 238              23                                     [WID]
# 239              23                                     [GUT]
# 240              26                                [WID, DIV]
# 241             NaN                                     [DIV]
# 242              24                                [WID, DDO]
# 243              25                      [WID, BER, WOL, LAM]
# 244              24                           [WID, LAM, URI]
# 245              25                                     [DES]
# 246              24                           [CAB, BER, DDO]
# 247              29                                     [DES]
# 248              21                                     [LAW]
# 249              32                                     [DES]
#
#                                        id    id_inst    ...      \
# 0    E1A2CC7A-C98E-2999-6040-A5E0E616E142  009756186    ...
# 1    145AF7DB-7A8C-E659-E251-69E4115ECFFD  010067972    ...
# 2    E8CE67BD-D35D-EF4B-6817-355DBB3737DC  010069355    ...
# 3    BC7EA9B8-5AA0-3F2D-C8E9-73F45DD2654F  011884540    ...
# 4    B37FFDED-3A4F-39A2-9485-3BEC97E450F9  013080416    ...
# 5    0ED28B06-D9F5-32C9-26A8-3F4D0D4A42BA  010198066    ...
# 6    47D42D6F-AD54-E781-742D-07224C29AA01  007861364    ...
# 7    9858E42E-0947-5B17-CC6C-18EBC346D951  009290341    ...
# 8    C4F5E2CE-9DD6-EB35-77AA-9A2EA2140B12  009800727    ...
# 9    5A91C56F-38CB-70FC-00B0-8EB4B930F346  011892956    ...
# 10   89226D80-11AE-AD79-5221-B018D676D862  008349053    ...
# 11   15F62A65-E3EF-0C32-8E43-5F66835A2FDA  001511136    ...
# 12   DA93873B-0AA0-2CCF-12A8-2889FA561BE1  008696424    ...
# 13   1F00D60A-A9F1-3734-B9AE-1A1D9738EB9B  002171980    ...
# 14   DE6BA768-1D8C-7DC3-FAB0-D3284254BDC4  004905559    ...
# 15   BF4993C8-54C9-CA64-813F-9A037C4381CD  008867014    ...
# 16   0D1CDE8E-901B-B7DE-399C-1817B6BA7C23  008697210    ...
# 17   3478E66F-1906-2D6B-DC81-F4D22A6AE92E  008697528    ...
# 18   4C1F68E0-4D89-BFBD-D69C-38ADEB2F65AE  008697585    ...
# 19   C1BC789D-4B91-EF62-E988-9BE5AEB87717  009534228    ...
# 20   2920FCF6-0B4D-A4A7-59EF-EE6703F6C0DB  005382073    ...
# 21   12F0CC24-3663-6495-760D-28123264BA27  001867274    ...
# 22   33D8A5B5-488A-6E70-92C0-C2B0D6C65267  002382950    ...
# 23   D1DA37E4-E040-912B-B6DB-9DFFFD9AF793  010245340    ...
# 24   647C78CF-CCCA-7448-095B-409192986BEB  001002045    ...
# 25   7F451468-5438-7FA6-1683-FC9AF0982AEF  010778910    ...
# 26   1066D984-2FE2-A4E7-BF9E-190F27183705  007511913    ...
# 27   63DC45A9-644B-33B0-E7E8-35DA3499E2B3  008002306    ...
# 28   7C52FB4C-0206-9CBB-FDD0-706E1703D4EC  005347392    ...
# 29   A39E9109-B9B1-1780-F468-FB15265B8621  008529253    ...
# ..                                    ...        ...    ...
# 220  F78792F9-21DE-0BA6-1FF3-09DC8A8D64E1  009210117    ...
# 221  42F63D3D-232A-D0DC-1C99-309137AFDD07  009210132    ...
# 222  368D984D-9814-F152-A050-39C21E95891F  001435036    ...
# 223  59AABB13-13F3-C9DA-C4ED-C83011437655  007541818    ...
# 224  EF742D10-E667-0761-FB33-F2526E5A0FB2  002375411    ...
# 225  BA1C4E28-3C34-EF70-125F-47E8442CDDF7  012034452    ...
# 226  98D19E17-004B-688A-FE42-DE584F7C6091  012034649    ...
# 227  FEDCCA47-D0D5-069B-E8B5-6200214B73F9  009789800    ...
# 228  91289C83-340F-053A-2898-45E99A2F6BD8  001545907    ...
# 229  CD5AFA7B-F49E-CC3B-39EE-07AB7515FCE5  003535846    ...
# 230  73117268-0EAC-CEBA-0ADB-61DFF6AC0BD7  000188040    ...
# 231  43CB65CC-0D9B-9B7A-1EA9-7BEE3C34BD28  000912600    ...
# 232  AD9C9542-26CE-C7EE-006A-079ED8563386  000681137    ...
# 233  43D2F218-C84D-1F96-A530-40FBDD0DE455  003202645    ...
# 234  D192A311-53BF-1961-8A00-0C3FBD330119  008205320    ...
# 235  55737F23-F88C-2028-706A-732E9FA037FD  008515805    ...
# 236  022BD3E1-61C3-644A-C635-5F5CFACFD6AC  001730936    ...
# 237  EC9F77F1-4D38-21E1-0908-A4D2A63CCFD9  008440210    ...
# 238  734B32F4-DF80-FDFD-A76A-241168E3FCE2  001203281    ...
# 239  66FE713C-24B5-3B30-3922-19EE085E1ED7  008903319    ...
# 240  E8CBC797-7339-366A-1E31-3E175656C9FC  009038910    ...
# 241  20A4B5EC-4169-7A82-78A7-E89FB8531524  010278973    ...
# 242  4B3D1EE2-87F9-D53B-5998-4795C5602A87  001379476    ...
# 243  3CC00132-CC63-BF8C-81BF-0412E038E420  008947934    ...
# 244  4F4E99EA-042C-7B2D-C368-E4E890ACA506  010279575    ...
# 245  79D81049-F4E7-AC16-EA3D-742976EE4664  009214473    ...
# 246  0864D556-6526-B8EC-2B22-098F650B01C6  010083728    ...
# 247  B571733B-A3E6-19FB-3596-FF649CB6336F  008038510    ...
# 248  18BE4798-BA2B-F1A2-F5BE-29C8505F1EEA  000563971    ...
# 249  5508BDF7-1046-3CF4-E3BC-48F269CBA4E7  009793113    ...
#
#                               source_record.rsrc_value  \
# 0                                                  NaN
# 1    http://pd.npr.org/anon.npr-mp3/npr/fa/2009/02/...
# 2    http://pd.npr.org/anon.npr-mp3/npr/newsnotes/2...
# 3                                                  NaN
# 4    http://pd.npr.org/anon.npr-mp3/npr/me/2012/02/...
# 5    http://pd.npr.org/anon.npr-mp3/npr/day/2006/12...
# 6                                                  NaN
# 7                                                  NaN
# 8    http://pd.npr.org/anon.npr-mp3/npr/atc/2005/10...
# 9    http://pd.npr.org/anon.npr-mp3/npr/atc/2009/05...
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
# 246                                                NaN
# 247                                                NaN
# 248                                                NaN
# 249                                                NaN
#
#     source_record.score_total  \
# 0                          10
# 1                          10
# 2                          10
# 3                          10
# 4                          10
# 5                           9
# 6                           9
# 7                          10
# 8                          10
# 9                          10
# 10                         10
# 11                         10
# 12                          9
# 13                         10
# 14                         10
# 15                         10
# 16                         10
# 17                         10
# 18                         10
# 19                         10
# 20                         10
# 21                          9
# 22                         10
# 23                         10
# 24                         10
# 25                          9
# 26                         10
# 27                          9
# 28                         10
# 29                          9
# ..                        ...
# 220                        10
# 221                        10
# 222                        10
# 223                        10
# 224                        10
# 225                         9
# 226                         9
# 227                        10
# 228                         9
# 229                         9
# 230                        10
# 231                         9
# 232                         9
# 233                         9
# 234                        10
# 235                        10
# 236                         9
# 237                        10
# 238                        10
# 239                        10
# 240                        10
# 241                        10
# 242                        10
# 243                         9
# 244                        10
# 245                        10
# 246                        10
# 247                        10
# 248                        10
# 249                        10
#
#                                      source_record.toc  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Overview: the roots of the racial wealth divid...
# 3                                                  NaN
# 4    Prologue: Between roses -- Undercitizens -- An...
# 5    Chairs in the ancient world, China & Africa --...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19   Part 1: Current trends in child victimization ...
# 20                   v. 1 1:1-9:50 -- v. 2. 9:51-24:53
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 220  Introduction / Kathleen deMarrais and Stephen ...
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225  The Guggenheim Museum : the New York context /...
# 226  Early days -- The rise of the rational market ...
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  Defining international education / Holly Moran...
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
# 246  Image, word and medicine in the Middle Ages / ...
# 247                                                NaN
# 248                                                NaN
# 249                                                NaN
#
#                                              sub_title  \
# 0             Asia and Europe in the American imperium
# 1                 inside Afghanistan after the Taliban
# 2       the story behind the U.S. racial wealth divide
# 3     the battle for the International Criminal Court.
# 4                                                  NaN
# 5                                            a history
# 6                         new histories for the Empire
# 7                                                  NaN
# 8              the autobiography of John Hope Franklin
# 9    a sinner's semester at America's holiest unive...
# 10              aging, gender, and body in North India
# 11                                                 NaN
# 12                                                 NaN
# 13                                 a historical survey
# 14                                                 NaN
# 15   facets of the feminine in Zoroastrian religiou...
# 16   the 2000 election, the constitution, and the c...
# 17                                                 NaN
# 18               the architecture of high construction
# 19   maltreatment, bullying and dating violence, pr...
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23         a history of government sponsored terrorism
# 24       symbolism and purpose in religious structures
# 25                                                 NaN
# 26                                                 NaN
# 27                     criticism after postcoloniality
# 28   the influence of the daguerreotype on American...
# 29                                                 NaN
# ..                                                 ...
# 220  methods of inquiry in education and the social...
# 221                                                NaN
# 222  a classic of the Chinese school of law; transl...
# 223                                                NaN
# 224                                                NaN
# 225  Frank Lloyd Wright and the making of the moder...
# 226  a history of risk, reward, and delusion on Wal...
# 227                                                NaN
# 228  a womanist vision of women's relationships in ...
# 229                                                NaN
# 230                                                NaN
# 231                   studies in honor of Edward Conze
# 232                                                NaN
# 233                                                NaN
# 234                 dynamics within and between groups
# 235                        swimming against the stream
# 236             selected essays of Bhikkhu Buddhadas̄a
# 237                                 la villa di Poppea
# 238  the section on Muslim sects in Kitāb al-milal ...
# 239                building vital programs on campuses
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                           birth of a modern nation
# 245                        Issey Miyake & Dai Fujiwara
# 246                                                NaN
# 247                              principles and design
# 248                                                NaN
# 249                                                NaN
#
#                                                  title  \
# 0                                   A world of regions
# 1                             The punishment of virtue
# 2                                  The color of wealth
# 3                                        The reckoning
# 4                        Behind the beautiful forevers
# 5                                               Chairs
# 6                                      Imperial Russia
# 7                                     Gideon's trumpet
# 8                                    Mirror to America
# 9                                The unlikely disciple
# 10                       White saris and sweet mangoes
# 11                                     Collected works
# 12   Nonlinear physics with Mathematica for scienti...
# 13                                       Chinese drama
# 14                                  Legal anthropology
# 15                               Evil, good and gender
# 16                               Breaking the deadlock
# 17                             University architecture
# 18                                     Petronas Towers
# 19                                 Child victimization
# 20                                                Luke
# 21   Partial differential equations of applied math...
# 22                      Mesoscopic phenomena in solids
# 23                                         TerrorStorm
# 24                                     Sacred geometry
# 25                               Classical archaeology
# 26                                   Giornale di bordo
# 27                                Refashioning futures
# 28                                        Mirror image
# 29                                         On religion
# ..                                                 ...
# 220                           Foundations for research
# 221                              School accountability
# 222                             The book of Lord Shang
# 223                             The critical landscape
# 224                    In the realm of a dying emperor
# 225                                     The Guggenheim
# 226                    The myth of the rational market
# 227                Child soldiers in international law
# 228                                 Just a sister away
# 229    Rameau and musical thought in the Enlightenment
# 230  Two Chinese philosophers: Chʻêng Ming-tao and ...
# 231                 Prajñāpāramitā and related systems
# 232                                        The Trinity
# 233                                 Cartas de relación
# 234                                    Group processes
# 235                          Innovative Buddhist women
# 236                                        Me and mine
# 237                                           Oplontis
# 238                         Muslim sects and divisions
# 239                Internationalizing higher education
# 240              The Oxford handbook of Jewish studies
# 241                                      Wheel of time
# 242              Arabic poetry: theory and development
# 243                                 Galileo in context
# 244                                            Ukraine
# 245                                       A-Poc making
# 246  Visualizing medieval medicine and natural hist...
# 247                            Architectural acoustics
# 248                        The constitution of liberty
# 249                                       Japan houses
#
#                                    title_link_friendly  \
# 0                                   a-world-of-regions
# 1                             the-punishment-of-virtue
# 2                                  the-color-of-wealth
# 3                                        the-reckoning
# 4                        behind-the-beautiful-forevers
# 5                                               chairs
# 6                                      imperial-russia
# 7                                      gideons-trumpet
# 8                                    mirror-to-america
# 9                                the-unlikely-disciple
# 10                       white-saris-and-sweet-mangoes
# 11                                     collected-works
# 12   nonlinear-physics-with-mathematica-for-scientists
# 13                                       chinese-drama
# 14                                  legal-anthropology
# 15                                evil-good-and-gender
# 16                               breaking-the-deadlock
# 17                             university-architecture
# 18                                     petronas-towers
# 19                                 child-victimization
# 20                                                luke
# 21   partial-differential-equations-of-applied-math...
# 22                      mesoscopic-phenomena-in-solids
# 23                                         terrorstorm
# 24                                     sacred-geometry
# 25                               classical-archaeology
# 26                                   giornale-di-bordo
# 27                                refashioning-futures
# 28                                        mirror-image
# 29                                         on-religion
# ..                                                 ...
# 220                           foundations-for-research
# 221                              school-accountability
# 222                             the-book-of-lord-shang
# 223                             the-critical-landscape
# 224                            in-the-realm-of-a-dying
# 225                                     the-guggenheim
# 226                    the-myth-of-the-rational-market
# 227                child-soldiers-in-international-law
# 228                                 just-a-sister-away
# 229                  rameau-and-musical-thought-in-the
# 230         two-chinese-philosophers-cheng-mingtao-and
# 231                     prajpramit-and-related-systems
# 232                                        the-trinity
# 233                                 cartas-de-relacion
# 234                                    group-processes
# 235                          innovative-buddhist-women
# 236                                        me-and-mine
# 237                                           oplontis
# 238                         muslim-sects-and-divisions
# 239                internationalizing-higher-education
# 240              the-oxford-handbook-of-jewish-studies
# 241                                      wheel-of-time
# 242               arabic-poetry-theory-and-development
# 243                                 galileo-in-context
# 244                                            ukraine
# 245                                        apoc-making
# 246  visualizing-medieval-medicine-and-natural-history
# 247                            architectural-acoustics
# 248                        the-constitution-of-liberty
# 249                                       japan-houses
#
#                                             title_sort  \
# 0                                     world of regions
# 1                                 punishment of virtue
# 2                                      color of wealth
# 3                                            reckoning
# 4                        Behind the beautiful forevers
# 5                                               Chairs
# 6                                      Imperial Russia
# 7                                     Gideon's trumpet
# 8                                    Mirror to America
# 9                                    unlikely disciple
# 10                       White saris and sweet mangoes
# 11                                     Collected works
# 12   Nonlinear physics with Mathematica for scienti...
# 13                                       Chinese drama
# 14                                  Legal anthropology
# 15                               Evil, good and gender
# 16                               Breaking the deadlock
# 17                             University architecture
# 18                                     Petronas Towers
# 19                                 Child victimization
# 20                                                Luke
# 21   Partial differential equations of applied math...
# 22                      Mesoscopic phenomena in solids
# 23                                         TerrorStorm
# 24                                     Sacred geometry
# 25                               Classical archaeology
# 26                                   Giornale di bordo
# 27                                Refashioning futures
# 28                                        Mirror image
# 29                                         On religion
# ..                                                 ...
# 220                           Foundations for research
# 221                              School accountability
# 222                                 book of Lord Shang
# 223                                 critical landscape
# 224                    In the realm of a dying emperor
# 225                                         Guggenheim
# 226                        myth of the rational market
# 227                Child soldiers in international law
# 228                                 Just a sister away
# 229    Rameau and musical thought in the Enlightenment
# 230  Two Chinese philosophers: Chʻêng Ming-tao and ...
# 231                 Prajñāpāramitā and related systems
# 232                                            Trinity
# 233                                 Cartas de relación
# 234                                    Group processes
# 235                          Innovative Buddhist women
# 236                                        Me and mine
# 237                                           Oplontis
# 238                         Muslim sects and divisions
# 239                Internationalizing higher education
# 240                  Oxford handbook of Jewish studies
# 241                                      Wheel of time
# 242              Arabic poetry: theory and development
# 243                                 Galileo in context
# 244                                            Ukraine
# 245                                       A-Poc making
# 246  Visualizing medieval medicine and natural hist...
# 247                            Architectural acoustics
# 248                            constitution of liberty
# 249                                       Japan houses
#
#                                                    url ut_count  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# 5                                                  NaN      NaN
# 6                                                  NaN      NaN
# 7                                                  NaN      NaN
# 8                                                  NaN      NaN
# 9                                                  NaN      NaN
# 10                                                 NaN      NaN
# 11                                                 NaN        3
# 12                                                 NaN       66
# 13                                                 NaN      NaN
# 14                                                 NaN        2
# 15                                                 NaN      NaN
# 16                                                 NaN      NaN
# 17                                                 NaN      NaN
# 18                                                 NaN      NaN
# 19                                                 NaN      NaN
# 20                                                 NaN   176904
# 21                                                 NaN      NaN
# 22                                                 NaN      NaN
# 23                                                 NaN      NaN
# 24                                                 NaN      NaN
# 25   [http://www.loc.gov/catdir/toc/ecip072/2006032...      NaN
# 26                                                 NaN      NaN
# 27                                                 NaN      NaN
# 28                                                 NaN      NaN
# 29                                                 NaN      NaN
# ..                                                 ...      ...
# 220                                                NaN      NaN
# 221                                                NaN      NaN
# 222                                                NaN      NaN
# 223                                                NaN      NaN
# 224                                                NaN      NaN
# 225                                                NaN      NaN
# 226  [http://nrs.harvard.edu/urn-3:hul.ebook:NLIB_2...      NaN
# 227                                                NaN      NaN
# 228                                                NaN      NaN
# 229                                                NaN      NaN
# 230                                                NaN      NaN
# 231                                                NaN     2716
# 232  [http://nrs.harvard.edu/urn-3:hul.ebookbatch.P...       16
# 233                                                NaN      NaN
# 234                                                NaN      NaN
# 235                                                NaN      NaN
# 236                                                NaN        3
# 237                                                NaN      NaN
# 238                                                NaN       16
# 239                                                NaN      NaN
# 240                                                NaN      NaN
# 241                                                NaN      NaN
# 242                                                NaN      NaN
# 243                                                NaN      NaN
# 244                                                NaN      NaN
# 245                                                NaN      NaN
# 246                                                NaN      NaN
# ...
# 229                                My elders taught me
# 230      Heritage, memory and the politics of identity
# 231                                Laughing at the Tao
# 232                  Rheinisches Museum für Philologie
# 233  Studies on Ottoman social history in the sixte...
# 234  Up and down the cline--the nature of grammatic...
# 235      Using social research in public policy making
# 236                New perspectives on advaita Vedānta
# 237               National Science Education Standards
# 238                                              Putin
# 239             The way of water and sprouts of virtue
# 240                       The ethnological imagination
# 241  What research has to say about reading instruc...
# 242                                       The passport
# 243                        South Asians in East Africa
# 244      Complex abelian varieties and theta functions
# 245                           The image of the Baroque
# 246                      The art of Richard Diebenkorn
# 247             Boom towns, bed towns and leisure time
# 248                    Andres Serrano, works 1983-1993
# 249               The politics of institutional choice
#
#                                    title_link_friendly  \
# 0                  privatisation-and-the-creation-of-a
# 1                  the-framing-and-ratification-of-the
# 2                                 canvases-and-careers
# 3               representations-of-war-in-ancient-rome
# 4                    poverty-and-charity-in-the-jewish
# 5                    cultural-identity-and-archaeology
# 6                                          cubic-forms
# 7                                   identitydifference
# 8                                    law-and-economics
# 9                                              beijing
# 10                                    sahala-di-gu-shi
# 11                             feminism-after-bourdieu
# 12                    worlds-of-the-silk-roads-ancient
# 13            wavelet-methods-for-time-series-analysis
# 14          political-community-and-the-north-atlantic
# 15                               electronic-literature
# 16                               setting-limits-fairly
# 17                          a-grammar-of-the-multitude
# 18                               society-and-discourse
# 19                                        peace-or-war
# 20                                           las-vegas
# 21                    electromagnetic-fields-and-waves
# 22                        a-survey-of-minimal-surfaces
# 23                        particles-sources-and-fields
# 24                            the-beast-in-the-boudoir
# 25                                    gesammelte-werke
# 26                    the-philosophy-of-social-science
# 27                  shaiva-devotional-songs-of-kashmir
# 28                   the-unity-of-knowledge-and-action
# 29                                          tonguetied
# ..                                                 ...
# 220                           buying-national-security
# 221                      on-practice-and-contradiction
# 222                                       zoo-design-3
# 223                          the-essential-ep-thompson
# 224                                      after-freedom
# 225              critical-essays-on-chinese-literature
# 226  learning-strategies-in-second-language-acquisi...
# 227                                regulating-intimacy
# 228                                     patrick-geddes
# 229                                my-elders-taught-me
# 230                heritage-memory-and-the-politics-of
# 231                                laughing-at-the-tao
# 232                  rheinisches-museum-fur-philologie
# 233               studies-on-ottoman-social-history-in
# 234                    up-and-down-the-clinethe-nature
# 235             using-social-research-in-public-policy
# 236                 new-perspectives-on-advaita-vednta
# 237               national-science-education-standards
# 238                                              putin
# 239                       the-way-of-water-and-sprouts
# 240                       the-ethnological-imagination
# 241                     what-research-has-to-say-about
# 242                                       the-passport
# 243                        south-asians-in-east-africa
# 244      complex-abelian-varieties-and-theta-functions
# 245                           the-image-of-the-baroque
# 246                      the-art-of-richard-diebenkorn
# 247                   boom-towns-bed-towns-and-leisure
# 248                      andres-serrano-works-19831993
# 249               the-politics-of-institutional-choice
#
#                                             title_sort  \
# 0    Privatisation and the creation of a market-bas...
# 1         Framing and ratification of the Constitution
# 2                                 Canvases and careers
# 3               Representations of war in ancient Rome
# 4    Poverty and charity in the Jewish community of...
# 5                    Cultural identity and archaeology
# 6                                          Cubic forms
# 7                                  Identity\difference
# 8                                    Law and economics
# 9                                              Beijing
# 10                                    Sahala di gu shi
# 11                             Feminism after Bourdieu
# 12        Worlds of the Silk Roads, ancient and modern
# 13            Wavelet methods for time series analysis
# 14     Political community and the North Atlantic area
# 15                               Electronic literature
# 16                               Setting limits fairly
# 17                            grammar of the multitude
# 18                               Society and discourse
# 19                                        Peace or war
# 20                                           Las Vegas
# 21                    Electromagnetic fields and waves
# 22                          survey of minimal surfaces
# 23                      Particles, sources, and fields
# 24                                beast in the boudoir
# 25                                    Gesammelte Werke
# 26                        philosophy of social science
# 27                  Shaiva devotional songs of Kashmir
# 28                       unity of knowledge and action
# 29                                         Tongue-tied
# ..                                                 ...
# 220                           Buying national security
# 221                      On practice and contradiction
# 222                                       Zoo design 3
# 223                            essential E.P. Thompson
# 224                                      After freedom
# 225              Critical essays on Chinese literature
# 226  Learning strategies in second language acquisi...
# 227                                Regulating intimacy
# 228                                     Patrick Geddes
# 229                                My elders taught me
# 230      Heritage, memory and the politics of identity
# 231                                Laughing at the Tao
# 232                  Rheinisches Museum für Philologie
# 233  Studies on Ottoman social history in the sixte...
# 234  Up and down the cline--the nature of grammatic...
# 235      Using social research in public policy making
# 236                New perspectives on advaita Vedānta
# 237               National Science Education Standards
# 238                                              Putin
# 239                 way of water and sprouts of virtue
# 240                           ethnological imagination
# 241  What research has to say about reading instruc...
# 242                                           passport
# 243                        South Asians in East Africa
# 244      Complex abelian varieties and theta functions
# 245                               image of the Baroque
# 246                          art of Richard Diebenkorn
# 247             Boom towns, bed towns and leisure time
# 248                    Andres Serrano, works 1983-1993
# 249                   politics of institutional choice
#
#                                                    url ut_count  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3    [http://www.loc.gov/catdir/toc/ecip0514/200501...      NaN
# 4                                                  NaN        1
# 5                                                  NaN      NaN
# 6                                                  NaN        1
# 7                                                  NaN      NaN
# 8                                                  NaN      NaN
# 9                                                  NaN      NaN
# 10                                                 NaN      NaN
# 11                                                 NaN      NaN
# 12                                                 NaN      NaN
# 13                                                 NaN      NaN
# 14                                                 NaN      NaN
# 15   [http://nrs.harvard.edu/urn-3:hul.ebookbatch.P...    22787
# 16                                                 NaN      NaN
# 17                                                 NaN      NaN
# 18                                                 NaN      NaN
# 19                                                 NaN      NaN
# 20                                                 NaN      NaN
# 21                                                 NaN      NaN
# 22                                                 NaN      NaN
# 23                                                 NaN      NaN
# 24                                                 NaN      NaN
# 25                                                 NaN        6
# 26                                                 NaN      NaN
# 27                                                 NaN        3
# 28                                                 NaN      NaN
# 29                                                 NaN      NaN
# ..                                                 ...      ...
# 220                                                NaN      NaN
# 221                                                NaN       85
# 222                                                NaN      NaN
# 223                                                NaN        1
# 224                                                NaN      NaN
# 225                                                NaN      NaN
# 226                                                NaN      NaN
# 227                                                NaN      NaN
# 228                                                NaN        1
# 229                                                NaN      NaN
# 230                                                NaN      NaN
# 231                                                NaN        1
# 232  [http://nrs.harvard.edu/urn-3:HUL.ejournals:sf...      NaN
# 233                                                NaN      NaN
# 234                                                NaN      NaN
# 235                                                NaN      NaN
# 236                                                NaN      NaN
# 237                                                NaN      NaN
# 238                                                NaN      NaN
# 239                                                NaN      NaN
# 240                                                NaN      NaN
# 241                                                NaN      NaN
# 242                                                NaN      NaN
# 243                                                NaN      NaN
# 244  [http://nrs.harvard.edu/urn-3:hul.ebookbatch.S...      NaN
# 245                                                NaN      NaN
# 246                                                NaN      NaN
# 247                                                NaN      NaN
# 248                                                NaN      NaN
# 249                                                NaN      NaN
#
#                                 ut_id wp_categories
# 0                                 NaN           NaN
# 1                                 NaN           NaN
# 2                                 NaN           NaN
# 3                                 NaN           NaN
# 4    12b611e8e0a771b77dc5a477daaef94c           NaN
# 5                                 NaN           NaN
# 6    2fa01adbe182531c44ec4e1c9dab238b           NaN
# 7                                 NaN           NaN
# 8                                 NaN           NaN
# 9                                 NaN           NaN
# 10                                NaN           NaN
# 11                                NaN           NaN
# 12                                NaN           NaN
# 13                                NaN           NaN
# 14                                NaN           NaN
# 15   8df21214de5c467292cbd49dc4af6d05           NaN
# 16                                NaN           NaN
# 17                                NaN           NaN
# 18                                NaN           NaN
# 19                                NaN           NaN
# 20                                NaN           NaN
# 21                                NaN           NaN
# 22                                NaN           NaN
# 23                                NaN           NaN
# 24                                NaN           NaN
# 25   501a2c0cda1ac23cf4047174284ba07a           NaN
# 26                                NaN           NaN
# 27   c8a96631cfa3b91bb604ddf4cc478995           NaN
# 28                                NaN           NaN
# 29                                NaN           NaN
# ..                                ...           ...
# 220                               NaN           NaN
# 221  76fe137a1f2a485ff190190538c79cef           NaN
# 222                               NaN           NaN
# 223  c92a386ea2c51ebe062ccd9ec28b7a81           NaN
# 224                               NaN           NaN
# 225                               NaN           NaN
# 226                               NaN           NaN
# 227                               NaN           NaN
# 228  f08c2d4f7f80a49fbe4a07e2e5ca494c           NaN
# 229                               NaN           NaN
# 230                               NaN           NaN
# 231  52f72c836e323c796a9ceab3fd1acdd2           NaN
# 232                               NaN           NaN
# 233                               NaN           NaN
# 234                               NaN           NaN
# 235                               NaN           NaN
# 236                               NaN           NaN
# 237                               NaN           NaN
# 238                               NaN           NaN
# 239                               NaN           NaN
# 240                               NaN           NaN
# 241                               NaN           NaN
# 242                               NaN           NaN
# 243                               NaN           NaN
# 244                               NaN           NaN
# 245                               NaN           NaN
# 246                               NaN           NaN
# 247                               NaN           NaN
# 248                               NaN           NaN
# 249                               NaN           NaN
#
# [250 rows x 291 columns]], dtype=object)

# %% [markdown]
# Check how many URLs we have to go through

# %%
len(flat_master_urls)
# Out:
# 2802

# %%
test_df = pd.concat(test_df_list)

# %%
test_df.columns
# Out:
# Index([u'call_num', u'creator', u'data_source', u'dataset_tag', u'format', u'height', u'height_numeric', u'holding_libs', u'id', u'id_inst', u'id_isbn', u'id_lccn', u'id_oclc', u'language', u'lcsh', u'loc_call_num_sort_order', u'loc_call_num_subject', u'note', u'online_avail', u'pages', u'pages_numeric', u'pub_date', u'pub_date_numeric', u'pub_location', u'publisher', u'score_checkouts_fac', u'score_checkouts_grad', u'score_checkouts_undergrad', u'score_course_texts', u'score_downloads', u'score_holding_libs', u'score_recalls', u'score_reserves', u'shelfrank', u'source_record.010a', u'source_record.010z', u'source_record.012a', u'source_record.012b', u'source_record.012l', u'source_record.0152', u'source_record.015a', u'source_record.0162', u'source_record.016a', u'source_record.020a', u'source_record.020b', u'source_record.020c', u'source_record.020z', u'source_record.0222', u'source_record.022a', u'source_record.022l', u'source_record.022y', u'source_record.022z', u'source_record.024a', u'source_record.024c', u'source_record.024d', u'source_record.025a', u'source_record.028a', u'source_record.028b', u'source_record.029a', u'source_record.029b', u'source_record.030a', u'source_record.032a', u'source_record.032b', u'source_record.033a', u'source_record.033b', u'source_record.034a', u'source_record.035a', u'source_record.035z', u'source_record.037a', u'source_record.037b', u'source_record.037c', u'source_record.037n', u'source_record.040a', u'source_record.040b', u'source_record.040c', u'source_record.040d', u'source_record.041a', u'source_record.041b', u'source_record.041d', u'source_record.041e', u'source_record.041g', u'source_record.041h', u'source_record.041j', u'source_record.042a', u'source_record.043a', u'source_record.044a', u'source_record.045a', u'source_record.045b', u'source_record.049a', u'source_record.049o', u'source_record.050a', u'source_record.050b', u'source_record.055a', u'source_record.055b', u'source_record.060a', u'source_record.060b', u'source_record.070a', u'source_record.070b', u'source_record.0722', u'source_record.072a', ...], dtype='object')
